# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
liver_df = pd.read_csv('Indian Liver Patient Dataset (ILPD).csv')
liver_df
# Out:
#      Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  \
# 0     65  Female   0.7  0.1      187    16    18  6.8  3.3       0.90
# 1     62    Male  10.9  5.5      699    64   100  7.5  3.2       0.74
# 2     62    Male   7.3  4.1      490    60    68  7.0  3.3       0.89
# 3     58    Male   1.0  0.4      182    14    20  6.8  3.4       1.00
# 4     72    Male   3.9  2.0      195    27    59  7.3  2.4       0.40
# ..   ...     ...   ...  ...      ...   ...   ...  ...  ...        ...
# 578   60    Male   0.5  0.1      500    20    34  5.9  1.6       0.37
# 579   40    Male   0.6  0.1       98    35    31  6.0  3.2       1.10
# 580   52    Male   0.8  0.2      245    48    49  6.4  3.2       1.00
# 581   31    Male   1.3  0.5      184    29    32  6.8  3.4       1.00
# 582   38    Male   1.0  0.3      216    21    24  7.3  4.4       1.50
#
#      Selector
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ..        ...
# 578         2
# ...

# %%
liver_df.columns
# Out:
# Index(['Age', 'Gender', 'TB', 'DB', 'Alkphos', 'Sgpt', 'Sgot', 'TP', 'ALB',
#        'A/G Ratio', 'Selector'],
#       dtype='object')

# %%
# Sample data (replace this with your actual dataset)
data = {
    'Gender': ['Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male' ]
}

#Create DataFrame
df = pd.DataFrame(data)

#Count occurences of each gender
gender_counts = df['Gender'].value_counts()

# Plot bar graph
plt.figure(figsize=(8, 6))
gender_counts.plot(kind='bar', color='skyblue')

#Add labels and title
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution of Genders')

#Show plot
plt.show()

# %%
# Sample data (replace this with your actual dataset)
data = {
    'Age': [45, 50, 35, 60, 55, 40, 30, 65, 70, 25],
    'Total Bilirubin': [1.2, 2.5, 3.0, 1.8, 2.0, 1.5, 2.2, 2.8, 3.5, 1.0]
}

#Create DataFrame
df = pd.DataFrame(data)

#Extract variable for scatter plot
x = df['Age']
y = df['Total Bilirubin']

#Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='orange', alpha=0.7)

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Total Bilrubin')
plt.title('Scatter plot: Age vs Total Bilrubin')

#Show plot
# Out:
# Text(0.5, 1.0, 'Scatter plot: Age vs Total Bilrubin')

# %%
# Sample data (replace this with your actual dataset)
data = {
    'Gender': ['Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male'],
    'SGPT': [35, 45, 40, 50, 55, 42, 48, 38, 60, 30]
}

# Create DataFrame
df = pd.DataFrame(data)

# Create violin plot
plt.figure(figsize=(10, 6))
sns.violinplot(x='Gender', y='SGPT', data=df, palette='muted')

# Add labels and title
plt.xlabel('Gender')
plt.ylabel('SGPT')
plt.title('Violin plot: SGPT Distribution by Gender')

# Show plot
plt.show()
